# %% [markdown]
# Login to the local tanzu cluster

# %% [markdown]
# kubectl vsphere login --server=tanzu.ne.local --vsphere-username administrator@vsphere.local --insecure-skip-tls-verify --tanzu-kubernetes-cluster-namespace niceneasy --tanzu-kubernetes-cluster-name wl-01

# %%
kubectl get all -A
# Out:
# NAMESPACE                      NAME                                                       READY   STATUS    RESTARTS   AGE
# cert-manager                   pod/cert-manager-cainjector-7954987fdb-qq8jw               1/1     Running   0          2d12h
# cert-manager                   pod/cert-manager-d7d54dbd5-vtvps                           1/1     Running   0          2d12h
# cert-manager                   pod/cert-manager-webhook-58c488c4f-s9plp                   1/1     Running   0          2d12h
# kube-system                    pod/antrea-agent-7wf9l                                     2/2     Running   0          2d12h
# kube-system                    pod/antrea-agent-bqgr7                                     2/2     Running   0          2d12h
# kube-system                    pod/antrea-agent-g4ndg                                     2/2     Running   0          2d12h
# ...
